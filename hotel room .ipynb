# %%
from tkinter import *
window=tkinter.Tk()

window.title("hotel room registration")
window.geometry('1000x1000')

title=Label(window,text="Tile")
title.grid(column=0, row=0)
t1=Entry(window,width=45)
t1.grid(column=1,row=0)

fn=tkinter.Label(window,text="First name")
fn.grid(column=0,row=1)
t2=Entry(window,width=45)
t2.grid(column=1,row=1)

ln=tkinter.Label(window,text="Last name")
ln.grid(column=0,row=2)
t3=Entry(window,width=45)
t3.grid(column=1,row=2)

sw=tkinter.Label(window,text="Share with")
sw.grid(column=0,row=3)
t3=Entry(window,width=45)
t3.grid(column=1,row=3)

bn=tkinter.Label(window,text="Business number")
bn.grid(column=0,row=4)
t4=Entry(window,width=45)
t4.grid(column=1,row=4)

mn=tkinter.Label(window,text="Mobile number")
mn.grid(column=0,row=5)
t5=Entry(window,width=45)
t5.grid(column=1,row=5)

email=tkinter.Label(window,text="Email address")
email.grid(column=0,row=6)
t6=Entry(window,width=45)
t6.grid(column=1,row=6)

doa=tkinter.Label(window,text="Date of arrival")
doa.grid(column=0,row=7)
t7=Entry(window,width=45)
t7.grid(column=1,row=7)

dod=tkinter.Label(window,text="Date of departure")
dod.grid(column=0,row=8)
t8=Entry(window,width=45)
t8.grid(column=1,row=8)

name=tkinter.Label(window,text="Name on credit card")
name.grid(column=0,row=9)
t9=Entry(window,width=45)
t9.grid(column=1,row=9)

cn=tkinter.Label(window,text="Credit card number")
cn.grid(column=0,row=10)
t10=Entry(window,width=45)
t10.grid(column=1,row=10)

date=tkinter.Label(window,text="Expiry date")
date.grid(column=0,row=11)
t11=Entry(window,width=45)
t11.grid(column=1,row=11)

cvv=tkinter.Label(window,text="CVV number")
cvv.grid(column=0,row=12)
t12=Entry(window,width=45)
t12.grid(column=1,row=12)

mode=tkinter.Label(window,text="Payment method")
mode.grid(column=0,row=13)
card=Checkbutton(window,text="credit card")
card.grid(column=1,row=13)
transfer=Checkbutton(window,text="Direct bank transfer")
transfer.grid(column=2,row=13)


nego=Label(window,text="\n----NEGOTIATED RATES----",font=("Arial Bold", 10))
nego.grid(column=0,row=14)

deluxes=Checkbutton(window,text="Deluxe room single\tR1700")
deluxes.grid(column=0,row=15)
deluxed=Checkbutton(window,text="Deluxe room double\tR1700")
deluxed.grid(column=1,row=15)

suites=Checkbutton(window,text="Suites room single\tR1700")
suites.grid(column=0,row=16)
suited=Checkbutton(window,text="Suites room double\tR1700")
suited.grid(column=1,row=16)

pref=Label(window,text="\n----ROOM PREFERENCES----",font=("Arial Bold", 10))
pref.grid(column=0,row=17)

king=Checkbutton(window,text="king bed\t")
king.grid(column=0,row=18)
twin=Checkbutton(window,text="Twin - Two single beds")
twin.grid(column=1,row=18)

line1=Label(window,text="\nthe above rates are quoted per room, per night. The rates include breakfast, 14% vat, and excludes 1% Tourism levy")
line1.grid(row=20)



window.mainloop()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-cdcdad208365> in <module>
#       1 from tkinter import *
# ----> 2 window=tkinter.Tk()
#       3
#       4 window.title("hotel room registration")
#       5 window.geometry('1000x1000')
#
# NameError: name 'tkinter' is not defined
