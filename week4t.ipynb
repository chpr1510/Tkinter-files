# %%
from tkinter import *
window=Tk()

window.title("Hotel room registration desk")
window.geometry('1000x1000')
window.config(bg="white")
#form=Label(window,text="FORM")

title=Label(window,text="Tile")
title.grid(column=0, row=0)
title.config(bg="white")
t1=Entry(window,width=45)
t1.grid(column=1,row=0)

fn=Label(window,text="First name",bg="white")
fn.grid(column=0,row=1)

t2=Entry(window,width=45,bg="white")
t2.grid(column=1,row=1)

ln=Label(window,text="Last name",bg="white")
ln.grid(column=0,row=2)
t3=Entry(window,width=45)
t3.grid(column=1,row=2)

sw=Label(window,text="Share with",bg="white")
sw.grid(column=0,row=3)
t3=Entry(window,width=45)
t3.grid(column=1,row=3)

bn=Label(window,text="Business number",bg="white")
bn.grid(column=0,row=4)
t4=Entry(window,width=45)
t4.grid(column=1,row=4)

mn=Label(window,text="Mobile number",bg="white")
mn.grid(column=0,row=5)
t5=Entry(window,width=45)
t5.grid(column=1,row=5)

email=Label(window,text="Email address",bg="white")
email.grid(column=0,row=6)
t6=Entry(window,width=45)
t6.grid(column=1,row=6)

doa=Label(window,text="Date of arrival",bg="white")
doa.grid(column=0,row=7)
t7=Entry(window,width=45)
t7.grid(column=1,row=7)

dod=Label(window,text="Date of departure",bg="white")
dod.grid(column=0,row=8)
t8=Entry(window,width=45)
t8.grid(column=1,row=8)

name=Label(window,text="Name on credit card",bg="white")
name.grid(column=0,row=9)
t9=Entry(window,width=45)
t9.grid(column=1,row=9)

cn=Label(window,text="Credit card number",bg="white")
cn.grid(column=0,row=10)
t10=Entry(window,width=45)
t10.grid(column=1,row=10)

date=Label(window,text="Expiry date",bg="white")
date.grid(column=0,row=11)
t11=Entry(window,width=45)
t11.grid(column=1,row=11)

cvv=Label(window,text="CVV number",bg="white")
cvv.grid(column=0,row=12)
t12=Entry(window,width=45)
t12.grid(column=1,row=12)

mode=Label(window,text="Payment method",bg="white")
mode.grid(column=0,row=13)
card=Checkbutton(window,text="credit card")
card.grid(column=1,row=13)
transfer=Checkbutton(window,text="Direct bank transfer")
transfer.grid(column=2,row=13)


nego=Label(window,text="----NEGOTIATED RATES----",font=("Arial Bold", 10),bg="white")
nego.grid(column=0,row=14)

deluxes=Checkbutton(window,text="Deluxe room single\tR1700")
deluxes.grid(column=0,row=15)
deluxed=Checkbutton(window,text="Deluxe room double\tR1700")
deluxed.grid(column=1,row=15)

suites=Checkbutton(window,text="Suites room single\tR1700")
suites.grid(column=0,row=16)
suited=Checkbutton(window,text="Suites room double\tR1700")
suited.grid(column=1,row=16)

pref=Label(window,text="----ROOM PREFERENCES----",font=("Arial Bold", 10),bg="white")
pref.grid(column=0,row=17)

king=Checkbutton(window,text="king bed\t")
king.grid(column=0,row=18)
twin=Checkbutton(window,text="Twin - Two single beds")
twin.grid(column=1,row=18)

line1=Label(window,text="\tThe above rates are quoted per room, per night. The rates include breakfast, 14% vat, and Excludes 1% Tourism Levy and a voluntary\nR10 donation to the arabella community trust that will be levis onto your account\n",bg="white")
line1.grid(column=0,row=19,columnspan=3)
#line2=Label(window,text=" R10 donation to the arabella community trust that will be levis onto your account")
#line2.grid(column=0,row=20,columnspan=3)

total=Label(window,text="Total amount payable Hotel and Spa",bg="white")
total.grid(column=0,row=21,columnspan=1)
zar=Label(window,text="ZAR_________x_________nights=ZAR_________due to Arabella",bg="white")
zar.grid(row=21,column=1,columnspan=4)

line2=Label(window,text="Credit card will be changed on receipt of this form and details will also be used to settle all incredentials not settle\non departure.A copy of the final folio will be sent to you should there be any unsettled changes",bg="white")
line2.grid(row=22,column=0,columnspan=4)

line3=Label(window,text="In order to qualify for the above rates, your booking needs to be made on or before 15th January 2016",bg="white")
line3.grid(row=23,column=0,columnspan=4)

line4=Label(window,text="\t\tTerms and conditions can be found on the next page",bg="white")
line4.grid(row=24,column=0,columnspan=4)

line5=Label(window,text="The rate is valid for seven days and after the conference dates.Check in time is 14:00 & check out time is 11:00",bg="white")
line5.grid(row=25,column=0,columnspan=4)

line6=Label(window,text="By your signature hereto,you are accepting all terms and conditions specified on this form and confirm that all information given is correct and accurate",bg="white")
line6.grid(row=26,column=0,columnspan=4)

sign=Label(window,text="Signature",bg="white")
sign.grid(row=27,column=0)
signe=Entry(window,width=30)
signe.grid(row=27,column=1)

pn=Label(window,text="Print Name",bg="white")
pn.grid(row=27,column=2)
pne=Entry(window,width=30)
pne.grid(row=27,column=3)

date=Label(window,text="Date",bg="white")
date.grid(row=28,column=0)
dat=Entry(window,width=30)
dat.grid(row=28,column=1)

submit=Button(window,text="Submit",fg="Black",bg="red")
submit.grid(row=29,column=1,columnspan=3)

window.mainloop()
